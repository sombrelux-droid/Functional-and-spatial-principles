# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import sys
sys.path.append("..")
from scripts import rewire, visual, indices

# %%
f = open('../Output/initials_nor.pckl', 'rb')
vertices_coord,initial_matrix = pickle.load(f)
f.close()

# %%
plt.rcParams['figure.figsize'] = [4, 4]
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.markersize'] = 8
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15

visual.plot_adjMatx(initial_matrix[0])
plt.savefig('../Output/figure/S1/1.eps',dpi=300, bbox_inches='tight')

# %%
visual.plot_network(vertices_coord[0], initial_matrix[0])
plt.savefig('../Output/figure/S1/2.eps',dpi=300, bbox_inches='tight')

# %%
f = open('../Output/Determ/S1.pckl', 'rb')
A_matrices = pickle.load(f)
f.close()

# %% [markdown]
# # $p_{function}=1$

# %%
key = 'p=0.0, q=0.0'
ind_list = [100, 300, 500, 1000]

plt.rcParams['figure.figsize'] = [16, 8]
for i, ind in enumerate(ind_list):
    p_in = 0.0
    plt.subplot(2,4,1+i)
    visual.plot_adjMatx(A_matrices[p_in][key][ind])
    if ind >0:
        plt.title(str(ind)+' Rewirings',fontsize=15)
    p_in = 1.0
    plt.subplot(2,4,5+i)
    visual.plot_adjMatx(A_matrices[p_in][key][ind])
plt.savefig('../Output/figure/S1/3.eps',dpi=300, bbox_inches='tight')

# %%
key = 'p=0.0, q=0.0'
ind_list = [100, 300, 500, 1000]

plt.rcParams['figure.figsize'] = [16, 8]
for i, ind in enumerate(ind_list):
    p_in = 0.0
    plt.subplot(2,4,1+i)
    visual.plot_network(vertices_coord[0], A_matrices[p_in][key][ind])
    if ind >0:
        plt.title(str(ind)+' Rewirings',fontsize=15)
    p_in = 1.0
    plt.subplot(2,4,5+i)
    visual.plot_network(vertices_coord[0], A_matrices[p_in][key][ind])
plt.savefig('../Output/figure/S1/4.svg',dpi=300, bbox_inches='tight')

# %% [markdown]
# # $p_{distance}=1$

# %%
key = 'p=1.0, q=0.0'
ind_list = [100, 300, 500, 1000]

plt.rcParams['figure.figsize'] = [16, 8]
for i, ind in enumerate(ind_list):
    p_in = 0.0
    plt.subplot(2,4,1+i)
    visual.plot_adjMatx(A_matrices[p_in][key][ind])
    if ind >0:
        plt.title(str(ind)+' Rewirings',fontsize=15)
    p_in = 1.0
    plt.subplot(2,4,5+i)
    visual.plot_adjMatx(A_matrices[p_in][key][ind])
plt.savefig('../Output/figure/S1/5.svg',dpi=300, bbox_inches='tight')

# %%
key = 'p=1.0, q=0.0'
ind_list = [100, 300, 500, 1000]

plt.rcParams['figure.figsize'] = [16, 8]
for i, ind in enumerate(ind_list):
    p_in = 0.0
    plt.subplot(2,4,1+i)
    visual.plot_network(vertices_coord[0], A_matrices[p_in][key][ind])
    if ind >0:
        plt.title(str(ind)+' Rewirings',fontsize=15)
    p_in = 1.0
    plt.subplot(2,4,5+i)
    visual.plot_network(vertices_coord[0], A_matrices[p_in][key][ind])
plt.savefig('../Output/figure/S1/6.eps',dpi=300, bbox_inches='tight')

# %% [markdown]
# # $p_{wave}=1$

# %%
key = 'p=0.0, q=1.0'
field = 'lat'
ind_list = [100, 300, 500, 1000]

plt.rcParams['figure.figsize'] = [16, 8]
for i, ind in enumerate(ind_list):
    p_in = 0.0
    plt.subplot(2,4,1+i)
    visual.plot_adjMatx(A_matrices[p_in][key][field][ind])
    if ind >0:
        plt.title(str(ind)+' Rewirings',fontsize=15)
    p_in = 1.0
    plt.subplot(2,4,5+i)
    visual.plot_adjMatx(A_matrices[p_in][key][field][ind])
plt.savefig('../Output/figure/S1/7.svg',dpi=300, bbox_inches='tight')

# %%
key = 'p=0.0, q=1.0'
field = 'lat'
ind_list = [100, 300, 500, 1000]

plt.rcParams['figure.figsize'] = [16, 8]
for i, ind in enumerate(ind_list):
    p_in = 0.0
    plt.subplot(2,4,1+i)
    visual.plot_network(vertices_coord[0], A_matrices[p_in][key][field][ind])
    if ind >0:
        plt.title(str(ind)+' Rewirings',fontsize=15)
    p_in = 1.0
    plt.subplot(2,4,5+i)
    visual.plot_network(vertices_coord[0], A_matrices[p_in][key][field][ind])
plt.savefig('../Output/figure/S1/8.eps',dpi=300, bbox_inches='tight')

# %%
key = 'p=0.0, q=1.0'
field = 'rad'
ind_list = [100, 300, 500, 1000]

plt.rcParams['figure.figsize'] = [16, 8]
for i, ind in enumerate(ind_list):
    p_in = 0.0
    plt.subplot(2,4,1+i)
    visual.plot_adjMatx(A_matrices[p_in][key][field][ind])
    if ind >0:
        plt.title(str(ind)+' Rewirings',fontsize=15)
    p_in = 1.0
    plt.subplot(2,4,5+i)
    visual.plot_adjMatx(A_matrices[p_in][key][field][ind])
plt.savefig('../Output/figure/S1/9.svg',dpi=300, bbox_inches='tight')

# %%
key = 'p=0.0, q=1.0'
field = 'rad'
ind_list = [100, 300, 500, 1000]

plt.rcParams['figure.figsize'] = [16, 8]
for i, ind in enumerate(ind_list):
    p_in = 0.0
    plt.subplot(2,4,1+i)
    visual.plot_network(vertices_coord[0], A_matrices[p_in][key][field][ind])
    if ind >0:
        plt.title(str(ind)+' Rewirings',fontsize=15)
    p_in = 1.0
    plt.subplot(2,4,5+i)
    visual.plot_network(vertices_coord[0], A_matrices[p_in][key][field][ind])
plt.savefig('../Output/figure/S1/10.svg',dpi=300, bbox_inches='tight')
